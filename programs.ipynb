# %% [markdown]
# # **PROGRAMS**
# ## **Here are the programs I created for my practice.**

# %% [markdown]
# ## Q:1, **Write a python program to add two numbers.**

# %%
a= 1
b= 2
print(a+b)
# Out:
# 3

# %% [markdown]
# ## Q:2,**Write a python program to find remainder when a number is divided by z.**

# %%
x = 9
y = 3
print("Remainder when x is divided by z",x % y)
# Out:
# Remainder when x is divided by z 0

# %% [markdown]
# ## Q:3, **Check the type of variable assigned using input () function.**

# %%
j = input("Enter the value of j:")
print(type(j))
# Out:
# Enter the value of j:hi
# <class 'str'>

# %% [markdown]
# ## Q:4, **Use comparison operator to find out whether ‘a’ given variable a is**
# ## **greater than ‘b’ or not. Take a = 34 and b = 80**

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
print("a is greater than b is", a>b)
# Out:
# Enter number 1: 4
# Enter number 2: 2
# a is greater than b is True

# %% [markdown]
# ## Q:5, **Write a python program to find an average of two numbers entered by the user**

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
print("The average of these two number is",(a+b)/2)
# Out:
# Enter number 1: 2
# Enter number 2: 9
# The average of these two number is 5.5

# %% [markdown]
# ## Q:6, **Write a python program to calculate the square of a number entered by the user**

# %%
a = int(input("Enter number 1: "))
print("The square of the number is",a**2)
# Out:
# Enter number 1: 3
# The square of the number is 9

# %% [markdown]
#  ## Q:7, **Write a python program to display a user entered name followed by Good Afternoon using input () function.**

# %%
name = input("Enter your name: ")
print(f"Good Afternoon,{name}")
# Out:
# Enter your name: mustafa
# Good Afternoon,mustafa

# %% [markdown]
# ## Q:8, **Write a program to fill in a letter template given below with name and date.**

# %%
letter = '''
Dear <|Name|>,
You are selected!
<|Date|>
'''
final_letter = letter.replace("<|Name|>", "Mustafa").replace("<|Date|>", "11/7/2025")
print(final_letter)
# Out:
# Dear Mustafa,
# You are selected!
# 11/7/2025

# %% [markdown]
# ## Q:9, **Write a program to detect double space in a string.**

# %%
a = ("How was   your day going ")

print(a.find('   '))
# Out:
# 7

# %% [markdown]
# ## Q:10, **Write a program to format the following letter using escape sequence character.**

# %%
letter = "Dear Mustafa,\nThe Python Is High Level Programining Language.\nThanks!"
  # delete the variable that replaced the built-in
print(letter)
# Out:
# Dear Mustafa,
# This Python Is High Level Programining Language.
# Thanks!
