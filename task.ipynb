# %% [markdown]
# # **Task**

# %%
userinput:dict={"Age":"17",
                "Name":"Mustafa",
                "Skills":("Python","Javascript")}
print(type(userinput),userinput["Name"])
Age=input("Enter Your Age For CNIC Validity:")
Age = int(Age) # Convert the input string to an integer
if Age >= 18:
  print("You Are Eligible For CNIC")
else:
  print("You Are Not Eligible For CNIC")
if Age<= 18:
  print("Invalid input. Please enter a number for your age.")
# Out:
# <class 'dict'> Mustafa
# Enter Your Age For CNIC Validity:19
# You Are Eligible For CNIC
